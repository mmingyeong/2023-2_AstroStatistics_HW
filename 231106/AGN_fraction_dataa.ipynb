# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#
# @Author: Mingyeong Yang (ggong@kasi.re.kr)
# @Date: 2023-10-06
# @Filename: hw3.ipynb

import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import sys
import math

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta

# Observed data
total_galaxies = 100
agn_galaxies = 30

# Calculate the parameters for the Beta distribution
alpha = agn_galaxies
beta_param = total_galaxies - agn_galaxies

# Define the range of values for p (AGN fraction)
p_values = np.linspace(0, 1, 1000)

# Calculate the PDF of the Beta distribution
pdf_values_b = beta.pdf(p_values, alpha, beta_param)

# Plot the posterior probability distribution
plt.plot(p_values, pdf_values_b)
plt.xlabel('AGN Fraction (p)')
plt.ylabel('Probability Density')
plt.title('Posterior Probability Distribution of AGN Fraction')
plt.show()

# %%
"""
Likehood = P(D|p)
Prior = P(p)
Posterior = P(p|D)
"""
# Out:
# '\nLikehood = P(D|p)\nPrior = P(p)\nPosterior = P(p|D)\n'

# %%
    """
    3.	Compute the same posterior probability distribution for the AGN fraction p as in question 2, 
    assuming that Choi et al. have already measured that p has a Gaussian distribution with mean 0.35 and r.m.s. 0.05? 
    Comment how different the outcome is compared to part 2.
    """
# Out:
# '\n3.\tCompute the same posterior probability distribution for the AGN fraction p as in question 2, \nassuming that Choi et al. have already measured that p has a Gaussian distribution with mean 0.35 and r.m.s. 0.05? \nComment how different the outcome is compared to part 2.\n'

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta

# Observed data
total_galaxies = 100
agn_galaxies = 30

# Calculate the parameters for the Beta distribution
alpha = agn_galaxies
beta_param = total_galaxies - agn_galaxies

def gaussian(x, mu, sigma):
    return (1/np.sqrt(2*np.pi*sigma**2))*np.exp(-(x-mu)**2/(2*sigma**2))

# Define the range of values for p (AGN fraction)
p_values = np.linspace(0, 1, 1000)

# Calculate the PDF of the gaussian distribution
mu = 0.35
sigma = 0.05
pdf_values_g = gaussian(p_values, mu, sigma)

# Plot the posterior probability distribution
plt.plot(p_values, pdf_values_g)
plt.xlabel('AGN Fraction (p)')
plt.ylabel('Probability Density')
plt.title('Posterior Probability Distribution of AGN Fraction')
plt.show()

# %%
plt.figure()
plt.plot(p_values, pdf_values_b, label="beta", color="b")
plt.plot(p_values, pdf_values_g, label="gaussian", color="r")
plt.xlabel('AGN Fraction (p)')
plt.ylabel('Probability Density')
plt.title('Posterior Probability Distribution of AGN Fraction')
plt.legend()
plt.show()

# %%
from scipy.integrate import quad
from scipy.stats import norm

mu = 0.35
sigma = 0.05

upper_limit = mu + 2*sigma
lower_limit = mu - 2*sigma

label_upper = "{:.3f}".format(upper_limit)
label_lower = "{:.3f}".format(lower_limit)

plt.figure()
plt.plot(p_values, pdf_values_g)
plt.fill_between(p_values, pdf_values_g,  where =( p_values<upper_limit) & (p_values>lower_limit), color = 'lightgreen', alpha=0.5)
plt.axvline(x=upper_limit, color='red', linestyle='--', label=f"{label_upper}")
plt.axvline(x=lower_limit, color='red', linestyle='--', label=f"{label_lower}")
plt.xlabel('AGN Fraction (p)')
plt.ylabel('Probability Density')
plt.title('Posterior Probability Distribution of AGN Fraction')
plt.legend()
plt.show()

# %%
upper_limit = mu + 2*sigma
lower_limit = mu - 2*sigma
print(upper_limit)
print(lower_limit)

#where =( p_values<mu*1.96 + sigma) & (p_values>mu*1.96 - sigma)
# Out:
# 0.44999999999999996
# 0.24999999999999997

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta

# Observed data
total_galaxies = 10000
agn_galaxies = 3427

# Calculate the parameters for the Beta distribution
alpha = agn_galaxies
beta_param = total_galaxies - agn_galaxies

# Define the range of values for p (AGN fraction)
p_values = np.linspace(0, 1, 100000)

# Calculate the PDF of the Beta distribution
pdf_values_b = beta.pdf(p_values, alpha, beta_param)

# Plot the posterior probability distribution
plt.plot(p_values, pdf_values_b)
plt.xlabel('AGN Fraction (p)')
plt.ylabel('Probability Density')
plt.title('Posterior Probability Distribution of AGN Fraction')
plt.show()

# %%
from scipy.integrate import quad
from scipy.stats import norm

mu = alpha/alpha+beta_param
var = (alpha*beta_param)/((alpha+beta_param)**2)*(alpha+beta_param+1)
sigma = np.sqrt(var)

#print(mu)
#print(sigma)

upper_limit = mu + 2*sigma
lower_limit = mu - 2*sigma

label_upper = "{:.3f}".format(upper_limit)
label_lower = "{:.3f}".format(lower_limit)

plt.figure()
plt.plot(p_values, pdf_values_b)
plt.fill_between(p_values, pdf_values_b,  where =( p_values<upper_limit) & (p_values>lower_limit), color = 'lightgreen', alpha=0.5)
plt.axvline(x=upper_limit, color='red', linestyle='--', label=f"{label_upper}")
plt.axvline(x=lower_limit, color='red', linestyle='--', label=f"{label_lower}")
plt.xlabel('AGN Fraction (p)')
plt.ylabel('Probability Density')
plt.title('Posterior Probability Distribution of AGN Fraction')
plt.legend()
plt.show()
# Out:
# 6574.0
# 47.46358980007728

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta

# Observed data
total_galaxies = 10000
agn_galaxies = 3427

# Calculate the parameters for the Beta distribution
alpha = agn_galaxies
beta_param = total_galaxies - agn_galaxies

def gaussian(x, mu, sigma):
    return (1/np.sqrt(2*np.pi*sigma**2))*np.exp(-(x-mu)**2/(2*sigma**2))

# Define the range of values for p (AGN fraction)
p_values = np.linspace(0, 1, 100000)

# Calculate the PDF of the gaussian distribution
mu = agn_galaxies/total_galaxies
sigma = 0.05
pdf_values_g = gaussian(p_values, mu, sigma)

# Plot the posterior probability distribution
plt.plot(p_values, pdf_values_g)
plt.xlabel('AGN Fraction (p)')
plt.ylabel('Probability Density')
plt.title('Posterior Probability Distribution of AGN Fraction')
plt.show()

# %%
plt.figure()
plt.plot(p_values, pdf_values_b, label="beta", color="b")
plt.plot(p_values, pdf_values_g, label="gaussian", color="r")
plt.xlabel('AGN Fraction (p)')
plt.ylabel('Probability Density')
plt.title('Posterior Probability Distribution of AGN Fraction')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta

# Observed data
total_galaxies = 10000
agn_galaxies = 3427

# Calculate the parameters for the Beta distribution
alpha = agn_galaxies
beta_param = total_galaxies - agn_galaxies

def gaussian(x, mu, sigma):
    return (1/np.sqrt(2*np.pi*sigma**2))*np.exp(-(x-mu)**2/(2*sigma**2))

# Define the range of values for p (AGN fraction)
p_values = np.linspace(0, 1, 100000)

# Calculate the PDF of the gaussian distribution
mu = agn_galaxies/total_galaxies
sigma = 0.05
pdf_values_g = gaussian(p_values, mu, sigma)

# Plot the posterior probability distribution
plt.plot(p_values, pdf_values_g)
plt.xlabel('AGN Fraction (p)')
plt.ylabel('Probability Density')
plt.title('Posterior Probability Distribution of AGN Fraction')
plt.show()

# %%
from scipy.integrate import quad
from scipy.stats import norm

mu = 0.35
sigma = 0.05

upper_limit = mu + 2*sigma
lower_limit = mu - 2*sigma

label_upper = "{:.3f}".format(upper_limit)
label_lower = "{:.3f}".format(lower_limit)

plt.figure()
plt.plot(p_values, pdf_values_g)
plt.fill_between(p_values, pdf_values_g,  where =( p_values<upper_limit) & (p_values>lower_limit), color = 'lightgreen', alpha=0.5)
plt.axvline(x=upper_limit, color='red', linestyle='--', label=f"{label_upper}")
plt.axvline(x=lower_limit, color='red', linestyle='--', label=f"{label_lower}")
plt.xlabel('AGN Fraction (p)')
plt.ylabel('Probability Density')
plt.title('Posterior Probability Distribution of AGN Fraction')
plt.legend()
plt.show()
