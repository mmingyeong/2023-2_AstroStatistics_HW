# %% [markdown]
# # Clustering analysis
#
# Requirements for this notebook:
#
# * python
# * jupyter
# * numpy
# * scipy
# * random
# * matplotlib
# * scikit-learn

# %% [markdown]
# Firstly we need to do the standard importing of python libraries

# %%
import random
from matplotlib import pyplot as plt
import numpy as np
import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# ## Centroid-based clustering
# Now we generate some clusters (in this case, two), and try to fit them using k-means clustering

# %%
n_cluster =2

plt.subplot(111)
for i in range(0,n_cluster):
    p = []
    mean = []
    mean.append(np.random.uniform(-1,1)+1.98*np.float64(i))
    mean.append(np.random.uniform(-1,1)-0.75*np.float64(i))
    print("Cluter {0:d}, mean(x) = {1:5.3f}, mean(y) = {2:5.3f}".format(i,mean[0],mean[1]))
    cov = np.zeros((2,2))
    for i_cov in range(0,2):
        var=np.random.uniform(0,0.25)
        cov[i_cov,i_cov] = var

    corr = np.random.uniform(-1,1)
    cov[0,1] = corr*np.sqrt(cov[0,0]*cov[1,1])
    cov[1,0] = corr*np.sqrt(cov[0,0]*cov[1,1])
    num_random = 1500
    x,y = np.random.multivariate_normal(mean,cov,num_random).T
    p = np.column_stack((x,y))
    plt.plot(x,y,'.')
    if i==0:
        p_two_cluster = p
    else:
        p_two_cluster=np.concatenate((p_two_cluster,p))



plt.show()
# Out:
# Cluter 0, mean(x) = -0.152, mean(y) = -0.401
# Cluter 1, mean(x) = 2.197, mean(y) = -0.747

# %%
print(len(p_two_cluster))
f = open('two_d_cluster.txt','w+')
for i in range(0,len(p_two_cluster)):
    string = "{0:6.2f} {1:6.2f}".format(p_two_cluster[i][0],p_two_cluster[i][1])
    f.write(string+"\n")
    
f.close()
# Out:
# 3000

# %% [markdown]
# Now we try to fit to this data using K-means

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, random_state=0).fit(p_two_cluster)

# %%
for i in range(0,2):
    print("Cluster number {0:d}, reconstructed center x={1:5.3f}, y={2:5.3f}".format(i,kmeans.cluster_centers_[i][0],kmeans.cluster_centers_[i][1]))
# Out:
# Cluster number 0, reconstructed center x=2.207, y=-0.735
# Cluster number 1, reconstructed center x=-0.150, y=-0.399

# %% [markdown]
# So we see that it recovers the true centers of the clusters. Does it correctly label the elements?

# %%
colour_index = np.array(kmeans.labels_)
plt.subplot(111)
x,y = zip(*p_two_cluster)
plt.scatter(x,y,c=colour_index)
plt.show()

# %% [markdown]
# Seems to work quite well.

# %% [markdown]
# ### Wrong number of clusters
#
# What if we generated data with more than two clusters, but reconstrcuted only two.

# %%
n_cluster =4

plt.subplot(111)
for i in range(0,n_cluster):
    p = []
    mean = []
    mean.append(np.random.uniform(-1,1)-2.938*np.float64(i))
    mean.append(np.random.uniform(-1,1)+(-1.76)**i*np.float64(i))
    print("Cluter {0:d}, mean(x) = {1:5.3f}, mean(y) = {2:5.3f}".format(i,mean[0],mean[1]))
    cov = np.zeros((2,2))
    for i_cov in range(0,2):
        var=np.random.uniform(0,0.25)
        cov[i_cov,i_cov] = var

    corr = np.random.uniform(-1,1)
    cov[0,1] = corr*np.sqrt(cov[0,0]*cov[1,1])
    cov[1,0] = corr*np.sqrt(cov[0,0]*cov[1,1])
    num_random = 1500
    x,y = np.random.multivariate_normal(mean,cov,num_random).T
    p = np.column_stack((x,y))
    plt.plot(x,y,'.')
    if i==0:
        p_four_cluster = p
    else:
        p_four_cluster=np.concatenate((p_four_cluster,p))



plt.show()
# Out:
# Cluter 0, mean(x) = -0.146, mean(y) = -0.344
# Cluter 1, mean(x) = -3.458, mean(y) = -2.573
# Cluter 2, mean(x) = -5.833, mean(y) = 6.987
# Cluter 3, mean(x) = -8.124, mean(y) = -16.593

# %% [markdown]
# Now we try to fit this using only two clusters

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, random_state=0).fit(p_four_cluster)

# %%
for i in range(0,2):
    print("Clusrer number {0:d}, reconstructed center x={1:5.3f}, y={2:5.3f}".format(i,kmeans.cluster_centers_[i][0],kmeans.cluster_centers_[i][1]))
# Out:
# Clusrer number 0, reconstructed center x=-3.144, y=1.355
# Clusrer number 1, reconstructed center x=-8.128, y=-16.594

# %% [markdown]
# It sucessfully recovered one of the clusters, but seemingly agregated the other three into a single cluster.

# %%
colour_index = np.array(kmeans.labels_)
plt.subplot(111)
x,y = zip(*p_four_cluster)
plt.scatter(x,y,c=colour_index)
plt.show()

# %% [markdown]
# We can use the Elbow method to determine the correct number of clusters.

# %%
from scipy.spatial.distance import cdist
# k means determine k
sse = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k).fit(p_four_cluster)
    sse.append(sum(np.min(cdist(p_four_cluster, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / p_four_cluster.shape[0])
 
# Plot the elbow
plt.plot(K, sse, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum-of-squared')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %% [markdown]
# As you can see, 4 or more clusters is needed to minise the sum-of-squared errors of the points with respect to mean centers of each clusters.

# %% [markdown]
# ## Connectivity-based clustering

# %% [markdown]
# Here is an example where simple linkage clustering won't work

# %%
n_cluster =2

plt.subplot(111)
for i in range(0,n_cluster):
    p = []
    mean = []
    if i==0: #generate simple localised cluster with Gaussian errors
        mean.append(np.random.uniform(-1,1)+0.67)
        mean.append(np.random.uniform(-1,1)-7.8)
        
        cov = np.zeros((2,2))
        for i_cov in range(0,2):
            var=np.random.uniform(0,0.5)
            cov[i_cov,i_cov] = var

        corr = np.random.uniform(-1,1)
        cov[0,1] = corr*np.sqrt(cov[0,0]*cov[1,1])
        cov[1,0] = corr*np.sqrt(cov[0,0]*cov[1,1])
        num_random = 200
        x,y = np.random.multivariate_normal(mean,cov,num_random).T
    else: #generate dispersed cluster
        parameters = np.random.uniform(-1,0.1,3)
        x = np.random.uniform(-5,5,200)
        y = []
        for x_individual in x:
            y.append(parameters[0] + parameters[1]*x_individual + parameters[2]*x_individual**2 + np.random.normal(0,0.25,1))
        
        
    p = np.column_stack((x,y))
    plt.plot(x,y,'.')
    if i==0:
        p_new = p
    else:
        p_new=np.concatenate((p_new,p))


print(len(p_new))
plt.show()
# Out:
# 400

# %% [markdown]
# If we try K-means with this, the answer won't be great.

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, random_state=0).fit(p_new)
colour_index = np.array(kmeans.labels_)
plt.subplot(111)
x,y = zip(*p_new)
plt.scatter(x,y,c=colour_index,s=1.0)
plt.show()

# %% [markdown]
# This doesn't look right. Instead, we should use [Connectivity-based clustering](https://en.wikipedia.org/wiki/Hierarchical_clustering)

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
lk = linkage(p_new,method='single',metric='euclidean')

# %% [markdown]
# This returns a 'linkage matrix', which gives us a dengrodgam

# %%
d=dendrogram(lk)
plt.ylabel('linkage distance')
plt.xlabel('data label')
plt.show()

# %% [markdown]
# From the dendrogram, we see that the varaition is explained through two main clusters, with the addition of a third that is very similar to the second. This is probably due to the tail, at one end of the parabola.
#
# Now we retrieve the clusters. By inspecting the dendrogram, we see we can make a cut at 1.0

# %%
from scipy.cluster.hierarchy import fcluster

max_d = 1.0
clusters = fcluster(lk, max_d, criterion='distance')
colour_index = np.array(clusters)
plt.subplot(111)
x,y = zip(*p_new)
plt.scatter(x,y,c=colour_index,s=1.0)
plt.show()

# %% [markdown]
# We almost recover the input clustering! But what if we had made a slightly different cut, at 0.9 for example.

# %%
max_d = 0.9
clusters = fcluster(lk, max_d, criterion='distance')
colour_index = np.array(clusters)
plt.subplot(111)
x,y = zip(*p_new)
plt.scatter(x,y,c=colour_index,s=1.0)
plt.show()

# %% [markdown]
# We now have three clusters, as the tail of parabola has been isolated.

# %% [markdown]
# ## DBSCAN

# %% [markdown]
# DBSCAN is an example of a density-based clustering algorithm. We will try it on the four cluster example from earlier.

# %%
from sklearn.cluster import DBSCAN
db = DBSCAN(eps=0.3, min_samples=10).fit(p_four_cluster)

# %%
labels = db.labels_
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
print(n_clusters_)
# Out:
# 4

# %% [markdown]
# DBSCAN has broken the data down into 4 clusters. But has it recovered the original clusters?

# %%
colour_index = np.array(labels)
plt.subplot(111)
x,y = zip(*p_four_cluster)
plt.scatter(x,y,c=colour_index,s=2)
plt.show()

# %% [markdown]
# It has! The purple region here represents noise, i.e. unclustered data points. Because each ellipsoidal cluster was Gaussian, it identified the central region as being different to the outskirts.
#
# Now let's see how it performs will the parabola case. (I changed the parameters a little bit for the parabola case, because the data is slightly sparse)

# %%
from sklearn.cluster import DBSCAN
db = DBSCAN(eps=1.0, min_samples=10).fit(p_new)
labels = db.labels_
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
print(n_clusters_)
# Out:
# 3

# %%
colour_index = np.array(labels)
plt.subplot(111)
x,y = zip(*p_new)
plt.scatter(x,y,c=colour_index,s=2)
plt.show()

# %% [markdown]
# So DBSCAN also recovers two clusters, the same as the input clusters. The end points of the parabola are considered outliers however, as the density is too low.
