# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#
# @Author: Mingyeong Yang (ggong@kasi.re.kr)
# @Date: 2023-09-08
# @Filename: HW1_ProbA.ipynb

# %%
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import sys

# %%
class handling_txts:
    """handling the txt file"""

    def __init__(self, file_name: str):
        self.file_name = file_name
        self.file = open(file_name, 'r')
        #print(self.file_name)

    def rd_savetolist(self):

        self.value_list = []
        while True:
            line = self.file.readline()
            line = line.strip()
            #print(line)
            if not line: break
            val = float(line)
            self.value_list.append(val)

        return self.value_list

    def rd_ln(self):

        list_len = len(self.value_list)
        return list_len

    def hist(self, color:str, bin=100):
        plt.figure()
        plt.hist(self.value_list, bins=bin, color=color)
        plt.legend(loc='upper left')
        plt.title(f"Histogram by {self.file_name} bins={bin}")
        plt.show()

# %%
# call the mock datas

mk1 = handling_txts("mock_data_1.txt")
mk2 = handling_txts("mock_data_2.txt")
mk3 = handling_txts("mock_data_3.txt")
mk4 = handling_txts("mock_data_4.txt")

mk1_list = mk1.rd_savetolist()
mk2_list = mk2.rd_savetolist()
mk3_list = mk3.rd_savetolist()
mk4_list = mk4.rd_savetolist()

print(mk1_list)
print(min(mk2_list))
print(max(mk1_list))
print(mk2_list)
print(min(mk2_list))
print(max(mk2_list))
print(mk3_list)
print(min(mk3_list))
print(max(mk3_list))
print(mk4_list)
print(min(mk4_list))
print(max(mk4_list))
# Out:
# [2.0815534906296964, 2.8924356076257824, 2.880811719671722, 3.347909736330017, 3.013036392663426, 2.4049852958174105, 2.0600185819032437, 2.7963677531022446, 2.569520020530839, 2.5327298483390694, 2.024463818317307, 1.7846575264245481, 1.8789071493616505, 2.293510005910198, 1.704681715995584, 1.6967315286518665, 2.9593889499240342, 2.798602577150662, 2.016462751716758, 1.970579207123627, 2.7441851532861676, 2.1792865616841017, 2.349138784801966, 2.437922996873702, 2.346604346648497, 2.1705240710720477, 2.6630708309205358, 2.187380072264475, 1.7208455165341934, 2.643056390272105, 2.31659025172548, 2.111285883708775, 2.672146243091166, 2.4578712493578037, 2.159066575328036, 2.699637396001803, 2.554299604062173, 2.2366141167332656, 2.592413219433072, 2.7732124385729513, 2.125741208610986, 2.468678511892398, 2.4853608853892033, 2.6024672581264543, 2.3408575563316836, 2.4464991558915585, 3.305526391473931, 2.1510995067552163, 2.1958761533791886, 2.523594933387783, 2.602625767217843, 2.600
# ...

# %%
print(mk1.rd_ln())
print(mk2.rd_ln())
print(mk3.rd_ln())
print(mk4.rd_ln())
# Out:
# 10000
# 10000
# 10000
# 10000

# %%
"""
mk1.hist(bin=100, color='o')
mk1.hist(bin=500, color='o')
mk1.hist(bin=1000, color='o')
mk1.hist(bin=5000, color='o')
"""
# Out:
# "\nmk1.hist(bin=100, color='o')\nmk1.hist(bin=500, color='o')\nmk1.hist(bin=1000, color='o')\nmk1.hist(bin=5000, color='o')\n"

# %%
"""
mk2.hist(bin=100, color='r')
mk2.hist(bin=500, color='r')
mk2.hist(bin=1000, color='r')
mk2.hist(bin=5000, color='r')
"""
# Out:
# "\nmk2.hist(bin=100, color='r')\nmk2.hist(bin=500, color='r')\nmk2.hist(bin=1000, color='r')\nmk2.hist(bin=5000, color='r')\n"

# %%
"""
mk3.hist(bin=100, color='g')
mk3.hist(bin=500, color='g')
mk3.hist(bin=1000, color='g')
mk3.hist(bin=5000, color='g')

mk3.hist(bin=10, color='g')
mk3.hist(bin=30, color='g')
mk3.hist(bin=50, color='g')
"""
# Out:
# "\nmk3.hist(bin=100, color='g')\nmk3.hist(bin=500, color='g')\nmk3.hist(bin=1000, color='g')\nmk3.hist(bin=5000, color='g')\n\nmk3.hist(bin=10, color='g')\nmk3.hist(bin=30, color='g')\nmk3.hist(bin=50, color='g')\n"

# %%
"""
mk4.hist(bin=100, color='b')
mk4.hist(bin=500, color='b')
mk4.hist(bin=1000, color='b')
mk4.hist(bin=5000, color='b')
"""
# Out:
# "\nmk4.hist(bin=100, color='b')\nmk4.hist(bin=500, color='b')\nmk4.hist(bin=1000, color='b')\nmk4.hist(bin=5000, color='b')\n"

# %%
# Then calculate the following for each dataset:

"""
1. Mean
2. Geometric mean (can you?!)
3. Median
4. Mode
5. Variance
6. Standard deviation
7. Skewness
8. Kurtosis
"""

class Cal_sample_statistic:
    """calculate sample statistic 
    
    1. Mean
    2. Geometric mean (can you?!)
    3. Median
    4. Mode
    5. Variance
    6. Standard deviation
    7. Skewness
    8. Kurtosis
    
    """

    def __init__(self, data: list):
        self.data = data
        self.num = len(data)

    def mean(self):
        # mean = sum / num
        sum = 0
        for i in self.data:
            sum = sum + i
        self.num = len(self.data)

        self.mean_val = sum / self.num
        
        return self.mean_val
    
    def geo_mean(self):
        # geo_mean = multip**(1/num)
        multip = 1
        for i in self.data:
            multip = multip*i

        self.geo_mean = multip**(1/self.num)

        return self.geo_mean
    
    def median(self):
        sortlist = sorted(self.data)
        flag = self.num%2
        half = int(self.num/2)
        #print(flag)
        if flag == 0:
            fir_term = half - 1
            sec_term = half
            self.median = (sortlist[fir_term] + sortlist[sec_term]) / 2
        else:
            fir_term = (self.num - 1)/2
            print(fir_term)
            self.median = sortlist[fir_term]

        return self.median
    
    def mode(self):
        # mode
        count_dic = {}
        for i in self.data:
            index = 0
            for j in self.data:
                if i==j:
                    index += 1
                else:
                    pass
            
            count_dic[i] = index
        sort_dic = sorted(count_dic.items(), key=lambda x:(-x[1], x[0]))
        mode_tup = sort_dic[0]

        frequency = mode_tup[1]

        if frequency==1:
            self.mode="Not exist"
        else:
            self.mode = mode_tup[0]

        return self.mode


    def variance(self):
        # sum((val - self.mean)**2)/self.num
        sum = 0
        meanval= self.mean()
        for i in self.data:
            comp = (i - meanval)**2
            sum = sum + comp
        
        self.varianceval = sum / self.num
        return self.varianceval

    def StandardDeviation(self):
        # variance**(1/2)
        val=self.variance()
        self.StandardDeviation_val = val**(1/2)
        return self.StandardDeviation_val

    def skewness(self):
        # sum((val - self.mean)**3)/self.num
        # StandardDeviation**(3)
        sum = 0
        meanval= self.mean()
        for i in self.data:
            comp = (i - meanval)**3
            sum = sum + comp
        
        top_comp = sum / self.num
        val = self.StandardDeviation()
        under_comp = val**3
        self.skewness = top_comp / under_comp

        return self.skewness

    def kurtosis(self):
        # sum((val - self.mean)**4)/self.num
        # StandardDeviation**4
        
        sum = 0
        meanval= self.mean()
        for i in self.data:
            comp = (i - meanval)**4
            sum = sum + comp
        
        top_comp = sum / self.num
        val = self.StandardDeviation()
        under_comp = val**4
        self.kurtosis = top_comp / under_comp

        return self.kurtosis

# %%
mk1_cal = Cal_sample_statistic(mk1_list)
mk1_cal_dic = {}
mk1_cal_dic["mean"] = mk1_cal.mean()
mk1_cal_dic["geo_mean"] = mk1_cal.geo_mean()
mk1_cal_dic["median"] = mk1_cal.median()
mk1_cal_dic["mode"] = mk1_cal.mode()
mk1_cal_dic["variance"] = mk1_cal.variance()
mk1_cal_dic["StandardDeviation"] = mk1_cal.StandardDeviation()
mk1_cal_dic["skewness"] = mk1_cal.skewness()
mk1_cal_dic["kurtosis"] = mk1_cal.kurtosis()

"""
print("calculate the following for mock_data_1.txt dataset")
print("mean: ", mk1_cal.mean())
print("geo_mean: ", mk1_cal.geo_mean())
print("median: ", mk1_cal.median())
print("mode: ", mk1_cal.mode())
print("variance: ", mk1_cal.variance())
print("StandardDeviation: ", mk1_cal.StandardDeviation())
print("skewness: ", mk1_cal.skewness())
print("kurtosis: ", mk1_cal.kurtosis())"""
# Out:
# '\nprint("calculate the following for mock_data_1.txt dataset")\nprint("mean: ", mk1_cal.mean())\nprint("geo_mean: ", mk1_cal.geo_mean())\nprint("median: ", mk1_cal.median())\nprint("mode: ", mk1_cal.mode())\nprint("variance: ", mk1_cal.variance())\nprint("StandardDeviation: ", mk1_cal.StandardDeviation())\nprint("skewness: ", mk1_cal.skewness())\nprint("kurtosis: ", mk1_cal.kurtosis())'

# %%
mk2_cal = Cal_sample_statistic(mk2_list)
mk2_cal_dic = {}
mk2_cal_dic["mean"] = mk2_cal.mean()
mk2_cal_dic["geo_mean"] = mk2_cal.geo_mean()
mk2_cal_dic["median"] = mk2_cal.median()
mk2_cal_dic["mode"] = mk2_cal.mode()
mk2_cal_dic["variance"] = mk2_cal.variance()
mk2_cal_dic["StandardDeviation"] = mk2_cal.StandardDeviation()
mk2_cal_dic["skewness"] = mk2_cal.skewness()
mk2_cal_dic["kurtosis"] = mk2_cal.kurtosis()

"""
print("calculate the following for mock_data_2.txt dataset")
print("mean: ", mk2_cal.mean())
print("geo_mean: ", mk2_cal.geo_mean())
print("median: ", mk2_cal.median())
print("mode: ", mk2_cal.mode())
print("variance: ", mk2_cal.variance())
print("StandardDeviation: ", mk2_cal.StandardDeviation())
print("skewness: ", mk2_cal.skewness())
print("kurtosis: ", mk2_cal.kurtosis())"""
# Out:
# '\nprint("calculate the following for mock_data_2.txt dataset")\nprint("mean: ", mk2_cal.mean())\nprint("geo_mean: ", mk2_cal.geo_mean())\nprint("median: ", mk2_cal.median())\nprint("mode: ", mk2_cal.mode())\nprint("variance: ", mk2_cal.variance())\nprint("StandardDeviation: ", mk2_cal.StandardDeviation())\nprint("skewness: ", mk2_cal.skewness())\nprint("kurtosis: ", mk2_cal.kurtosis())'

# %%
mk3_cal = Cal_sample_statistic(mk3_list)
mk3_cal_dic = {}
mk3_cal_dic["mean"] = mk3_cal.mean()
mk3_cal_dic["geo_mean"] = mk3_cal.geo_mean()
mk3_cal_dic["median"] = mk3_cal.median()
mk3_cal_dic["mode"] = mk3_cal.mode()
mk3_cal_dic["variance"] = mk3_cal.variance()
mk3_cal_dic["StandardDeviation"] = mk3_cal.StandardDeviation()
mk3_cal_dic["skewness"] = mk3_cal.skewness()
mk3_cal_dic["kurtosis"] = mk3_cal.kurtosis()

"""
print("calculate the following for mock_data_3.txt dataset")
print("mean: ", mk3_cal.mean())
print("geo_mean: ", mk3_cal.geo_mean())
print("median: ", mk3_cal.median())
print("mode: ", mk3_cal.mode())
print("variance: ", mk3_cal.variance())
print("StandardDeviation: ", mk3_cal.StandardDeviation())
print("skewness: ", mk3_cal.skewness())
print("kurtosis: ", mk3_cal.kurtosis())"""
# Out:
# '\nprint("calculate the following for mock_data_3.txt dataset")\nprint("mean: ", mk3_cal.mean())\nprint("geo_mean: ", mk3_cal.geo_mean())\nprint("median: ", mk3_cal.median())\nprint("mode: ", mk3_cal.mode())\nprint("variance: ", mk3_cal.variance())\nprint("StandardDeviation: ", mk3_cal.StandardDeviation())\nprint("skewness: ", mk3_cal.skewness())\nprint("kurtosis: ", mk3_cal.kurtosis())'

# %%
mk4_cal = Cal_sample_statistic(mk4_list)
mk4_cal_dic = {}
mk4_cal_dic["mean"] = mk4_cal.mean()
mk4_cal_dic["geo_mean"] = mk4_cal.geo_mean()
mk4_cal_dic["median"] = mk4_cal.median()
mk4_cal_dic["mode"] = mk4_cal.mode()
mk4_cal_dic["variance"] = mk4_cal.variance()
mk4_cal_dic["StandardDeviation"] = mk4_cal.StandardDeviation()
mk4_cal_dic["skewness"] = mk4_cal.skewness()
mk4_cal_dic["kurtosis"] = mk4_cal.kurtosis()


"""
del float
del int
del bool

print("calculate the following for mock_data_4.txt dataset")
print("mean: ", mk4_cal.mean())
print("geo_mean: ", mk4_cal.geo_mean())
print("median: ", mk4_cal.median())
print("mode: ", mk4_cal.mode())
print("variance: ", mk4_cal.variance())
print("StandardDeviation: ", mk4_cal.StandardDeviation())
print("skewness: ", mk4_cal.skewness())
print("kurtosis: ", mk4_cal.kurtosis())"""
# Out:
# '\ndel float\ndel int\ndel bool\n\nprint("calculate the following for mock_data_4.txt dataset")\nprint("mean: ", mk4_cal.mean())\nprint("geo_mean: ", mk4_cal.geo_mean())\nprint("median: ", mk4_cal.median())\nprint("mode: ", mk4_cal.mode())\nprint("variance: ", mk4_cal.variance())\nprint("StandardDeviation: ", mk4_cal.StandardDeviation())\nprint("skewness: ", mk4_cal.skewness())\nprint("kurtosis: ", mk4_cal.kurtosis())'

# %%
#Prob B

mk1_subset1 = mk1_list[0:1000]
mk1_subset2 = mk1_list[1000:2000]
mk1_subset3 = mk1_list[2000:3000]
mk1_subset4 = mk1_list[3000:4000]
mk1_subset5 = mk1_list[4000:5000]
mk1_subset6 = mk1_list[5000:6000]
mk1_subset7 = mk1_list[6000:7000]
mk1_subset8 = mk1_list[7000:8000]
mk1_subset9 = mk1_list[8000:9000]
mk1_subset10 = mk1_list[9000:10000]

subset_list = []
subset_list.append(mk1_subset1)
subset_list.append(mk1_subset2)
subset_list.append(mk1_subset3)
subset_list.append(mk1_subset4)
subset_list.append(mk1_subset5)
subset_list.append(mk1_subset6)
subset_list.append(mk1_subset7)
subset_list.append(mk1_subset8)
subset_list.append(mk1_subset9)
subset_list.append(mk1_subset10)

skewness_list = []
kurtosis_list = []
# newfile.py
f = open("hw1_proB_1.txt", 'w')
index = 1
for dataset in subset_list:
    mk_cal = Cal_sample_statistic(dataset)

    mk_cal_dic = {}
    mk_cal_dic["mean"] = mk_cal.mean()
    mk_cal_dic["geo_mean"] = mk_cal.geo_mean()
    mk_cal_dic["median"] = mk_cal.median()
    mk_cal_dic["mode"] = mk_cal.mode()
    mk_cal_dic["variance"] = mk_cal.variance()
    mk_cal_dic["StandardDeviation"] = mk_cal.StandardDeviation()
    mk_cal_dic["skewness"] = mk_cal.skewness()
    mk_cal_dic["kurtosis"] = mk_cal.kurtosis()

    f.write(f"<calculate the following for subset dataset {index}>\n")
    #f.write(f"mean: {mk_cal.mean()}\n")
    #f.write(f"geo_mean: {mk_cal.geo_mean()}\n")
    #f.write(f"median: {mk_cal.median()}\n")
    #f.write(f"mode: {mk_cal.mode()}\n")
    #f.write(f"variance: {mk_cal.variance()}\n")
    #f.write(f"StandardDeviation: {mk_cal.StandardDeviation()}\n")
    #f.write(f"skewness: {mk_cal.skewness()}\n")
    #f.write(f"kurtosis: {mk_cal.kurtosis()}\n")
    #f.write("\n")


    #plt.plot(mk_cal_dic.keys(), mk_cal_dic.values(), 'o--', linewidth=1, label=f"subset {index}")
    #print("skewness")
    skewness_list.append(mk_cal_dic['skewness'])
    kurtosis_list.append(mk_cal_dic['kurtosis'])
    #print(f" skewness {mk_cal_dic['skewness']}")
    #print("kurtosis")
    #print(f" kurtosis {mk_cal_dic['kurtosis']}")

    index += 1

f.close()

print(skewness_list)
print(kurtosis_list)

skewness_list_cal = Cal_sample_statistic(skewness_list)
mu = skewness_list_cal.mean()
sigma = skewness_list_cal.StandardDeviation()
print(f"mu = {mu}, sigma = {sigma}")

kurtosis_list_cal = Cal_sample_statistic(kurtosis_list)
mu = kurtosis_list_cal.mean()
sigma = kurtosis_list_cal.StandardDeviation()
print(f"mu = {mu}, sigma = {sigma}")
# Out:
# [0.09575763322813595, -0.16177283808103388, -0.10972560898072747, 0.05126125048111259, -0.12599935871928417, 0.14122203703015895, 0.09983087668837057, 0.0021901101485645707, 0.12405175635471381, -0.02217250661484894]
# [2.933979479546409, 3.015858588822157, 2.6653909040907684, 3.091474810026859, 2.8844542102131303, 3.179038627921752, 3.1233245298773853, 3.0850576896986617, 3.210962902545103, 3.029646535931132]
# mu = 0.0094643351535162, sigma = 0.10525332540973201
# mu = 3.021918827867336, sigma = 0.15276466055968413

# %%
numlist= range(10)
plt.figure()
plt.plot(0, mk1_cal_dic["kurtosis"], 'bo-', linewidth=1, label="Dataset1.txt")
index = 1
for dataset in subset_list:
    mk_cal = Cal_sample_statistic(dataset)
    mean_val = mk_cal.kurtosis()
    plt.plot(index, mean_val, 'o--', linewidth=1, label=index)
    index += 1
plt.title(f"kurtosis plot of subsets of Dataset1.txt")
#plt.legend(loc='best')
plt.show()

# %%
#Prob B

mk2_subset1 = mk2_list[0:1000]
mk2_subset2 = mk2_list[1000:2000]
mk2_subset3 = mk2_list[2000:3000]
mk2_subset4 = mk2_list[3000:4000]
mk2_subset5 = mk2_list[4000:5000]
mk2_subset6 = mk2_list[5000:6000]
mk2_subset7 = mk2_list[6000:7000]
mk2_subset8 = mk2_list[7000:8000]
mk2_subset9 = mk2_list[8000:9000]
mk2_subset10 = mk2_list[9000:10000]

subset_list = []
subset_list.append(mk2_subset1)
subset_list.append(mk2_subset2)
subset_list.append(mk2_subset3)
subset_list.append(mk2_subset4)
subset_list.append(mk2_subset5)
subset_list.append(mk2_subset6)
subset_list.append(mk2_subset7)
subset_list.append(mk2_subset8)
subset_list.append(mk2_subset9)
subset_list.append(mk2_subset10)

skewness_list = []
kurtosis_list = []
# newfile.py
f = open("hw1_proB_1.txt", 'w')
index = 1
for dataset in subset_list:
    mk_cal = Cal_sample_statistic(dataset)

    mk_cal_dic = {}
    mk_cal_dic["mean"] = mk_cal.mean()
    mk_cal_dic["geo_mean"] = mk_cal.geo_mean()
    mk_cal_dic["median"] = mk_cal.median()
    mk_cal_dic["mode"] = mk_cal.mode()
    mk_cal_dic["variance"] = mk_cal.variance()
    mk_cal_dic["StandardDeviation"] = mk_cal.StandardDeviation()
    mk_cal_dic["skewness"] = mk_cal.skewness()
    mk_cal_dic["kurtosis"] = mk_cal.kurtosis()

    f.write(f"<calculate the following for subset dataset {index}>\n")
    #f.write(f"mean: {mk_cal.mean()}\n")
    #f.write(f"geo_mean: {mk_cal.geo_mean()}\n")
    #f.write(f"median: {mk_cal.median()}\n")
    #f.write(f"mode: {mk_cal.mode()}\n")
    #f.write(f"variance: {mk_cal.variance()}\n")
    #f.write(f"StandardDeviation: {mk_cal.StandardDeviation()}\n")
    #f.write(f"skewness: {mk_cal.skewness()}\n")
    #f.write(f"kurtosis: {mk_cal.kurtosis()}\n")
    #f.write("\n")


    #plt.plot(mk_cal_dic.keys(), mk_cal_dic.values(), 'o--', linewidth=1, label=f"subset {index}")
    #print("skewness")
    skewness_list.append(mk_cal_dic['skewness'])
    kurtosis_list.append(mk_cal_dic['kurtosis'])
    #print(f" skewness {mk_cal_dic['skewness']}")
    #print("kurtosis")
    #print(f" kurtosis {mk_cal_dic['kurtosis']}")

    index += 1

f.close()

print(skewness_list)
print(kurtosis_list)

skewness_list_cal = Cal_sample_statistic(skewness_list)
mu = skewness_list_cal.mean()
sigma = skewness_list_cal.StandardDeviation()
print(f"mu = {mu}, sigma = {sigma}")

kurtosis_list_cal = Cal_sample_statistic(kurtosis_list)
mu = kurtosis_list_cal.mean()
sigma = kurtosis_list_cal.StandardDeviation()
print(f"mu = {mu}, sigma = {sigma}")
# Out:
# [0.1256775113989512, 0.10851278475070665, -0.02929698364515778, -0.08711926902096166, 0.07419974465953064, 0.2234355924130936, 0.007730463230614208, 0.02025136276425956, 0.07248166673867679, 0.1245789388595356]
# [2.917384736093718, 2.8731127957814326, 3.0112792470586336, 2.8960359564319726, 2.836334808216459, 3.2777085418582783, 3.11328753985225, 2.9890796757236084, 2.7288161344525212, 2.845764721071054]
# mu = 0.06404518121492488, sigma = 0.08465963446849745
# mu = 2.948880415653993, sigma = 0.14896983880876086

# %%
#Prob B

mk3_subset1 = mk3_list[0:1000]
mk3_subset2 = mk3_list[1000:2000]
mk3_subset3 = mk3_list[2000:3000]
mk3_subset4 = mk3_list[3000:4000]
mk3_subset5 = mk3_list[4000:5000]
mk3_subset6 = mk3_list[5000:6000]
mk3_subset7 = mk3_list[6000:7000]
mk3_subset8 = mk3_list[7000:8000]
mk3_subset9 = mk3_list[8000:9000]
mk3_subset10 = mk3_list[9000:10000]

subset_list = []
subset_list.append(mk3_subset1)
subset_list.append(mk3_subset2)
subset_list.append(mk3_subset3)
subset_list.append(mk3_subset4)
subset_list.append(mk3_subset5)
subset_list.append(mk3_subset6)
subset_list.append(mk3_subset7)
subset_list.append(mk3_subset8)
subset_list.append(mk3_subset9)
subset_list.append(mk3_subset10)

skewness_list = []
kurtosis_list = []
# newfile.py
f = open("hw1_proB_1.txt", 'w')
index = 1
for dataset in subset_list:
    mk_cal = Cal_sample_statistic(dataset)

    mk_cal_dic = {}
    mk_cal_dic["mean"] = mk_cal.mean()
    mk_cal_dic["geo_mean"] = mk_cal.geo_mean()
    mk_cal_dic["median"] = mk_cal.median()
    mk_cal_dic["mode"] = mk_cal.mode()
    mk_cal_dic["variance"] = mk_cal.variance()
    mk_cal_dic["StandardDeviation"] = mk_cal.StandardDeviation()
    mk_cal_dic["skewness"] = mk_cal.skewness()
    mk_cal_dic["kurtosis"] = mk_cal.kurtosis()

    f.write(f"<calculate the following for subset dataset {index}>\n")
    #f.write(f"mean: {mk_cal.mean()}\n")
    #f.write(f"geo_mean: {mk_cal.geo_mean()}\n")
    #f.write(f"median: {mk_cal.median()}\n")
    #f.write(f"mode: {mk_cal.mode()}\n")
    #f.write(f"variance: {mk_cal.variance()}\n")
    #f.write(f"StandardDeviation: {mk_cal.StandardDeviation()}\n")
    #f.write(f"skewness: {mk_cal.skewness()}\n")
    #f.write(f"kurtosis: {mk_cal.kurtosis()}\n")
    #f.write("\n")


    #plt.plot(mk_cal_dic.keys(), mk_cal_dic.values(), 'o--', linewidth=1, label=f"subset {index}")
    #print("skewness")
    skewness_list.append(mk_cal_dic['skewness'])
    kurtosis_list.append(mk_cal_dic['kurtosis'])
    #print(f" skewness {mk_cal_dic['skewness']}")
    #print("kurtosis")
    #print(f" kurtosis {mk_cal_dic['kurtosis']}")

    index += 1

f.close()

print(skewness_list)
print(kurtosis_list)

skewness_list_cal = Cal_sample_statistic(skewness_list)
mu = skewness_list_cal.mean()
sigma = skewness_list_cal.StandardDeviation()
print(f"mu = {mu}, sigma = {sigma}")

kurtosis_list_cal = Cal_sample_statistic(kurtosis_list)
mu = kurtosis_list_cal.mean()
sigma = kurtosis_list_cal.StandardDeviation()
print(f"mu = {mu}, sigma = {sigma}")
# Out:
# [0.17015433293519475, 0.2965969497879963, 0.35415205724655435, 0.3130493006853107, 0.25396947484105503, 0.2211234361783912, 0.2241042855603896, 0.20841474962740483, 0.2888345795414705, 0.27918118996106395]
# [2.8161261786548226, 3.067806147609972, 3.168935577381038, 3.0128084384313234, 2.9941662968791776, 2.8450217050961526, 2.875336729361191, 2.6403572911394093, 3.1146793328096556, 3.287002584913436]
# mu = 0.2609580356364831, sigma = 0.05270473065419619
# mu = 2.9822240282276176, sigma = 0.18122048330483728

# %%
#Prob B

mk4_subset1 = mk4_list[0:1000]
mk4_subset2 = mk4_list[1000:2000]
mk4_subset3 = mk4_list[2000:3000]
mk4_subset4 = mk4_list[3000:4000]
mk4_subset5 = mk4_list[4000:5000]
mk4_subset6 = mk4_list[5000:6000]
mk4_subset7 = mk4_list[6000:7000]
mk4_subset8 = mk4_list[7000:8000]
mk4_subset9 = mk4_list[8000:9000]
mk4_subset10 = mk4_list[9000:10000]

subset_list = []
subset_list.append(mk4_subset1)
subset_list.append(mk4_subset2)
subset_list.append(mk4_subset3)
subset_list.append(mk4_subset4)
subset_list.append(mk4_subset5)
subset_list.append(mk4_subset6)
subset_list.append(mk4_subset7)
subset_list.append(mk4_subset8)
subset_list.append(mk4_subset9)
subset_list.append(mk4_subset10)

#plt.figure(figsize=(30,10))
#plt.plot(mk4_cal_dic.keys(), mk4_cal_dic.values(), 'bo-', linewidth=1, label="Dataset4.txt")
#plt.legend(loc='upper left')
#plt.title(f"Cal_sample_statistic plot of subsets of Dataset4.txt")

skewness_list = []
kurtosis_list = []
# newfile.py
f = open("hw1_proB_1.txt", 'w')
index = 1
for dataset in subset_list:
    mk_cal = Cal_sample_statistic(dataset)

    mk_cal_dic = {}
    mk_cal_dic["mean"] = mk_cal.mean()
    mk_cal_dic["geo_mean"] = mk_cal.geo_mean()
    mk_cal_dic["median"] = mk_cal.median()
    mk_cal_dic["mode"] = mk_cal.mode()
    mk_cal_dic["variance"] = mk_cal.variance()
    mk_cal_dic["StandardDeviation"] = mk_cal.StandardDeviation()
    mk_cal_dic["skewness"] = mk_cal.skewness()
    mk_cal_dic["kurtosis"] = mk_cal.kurtosis()

    f.write(f"<calculate the following for subset dataset {index}>\n")
    #f.write(f"mean: {mk_cal.mean()}\n")
    #f.write(f"geo_mean: {mk_cal.geo_mean()}\n")
    #f.write(f"median: {mk_cal.median()}\n")
    #f.write(f"mode: {mk_cal.mode()}\n")
    #f.write(f"variance: {mk_cal.variance()}\n")
    #f.write(f"StandardDeviation: {mk_cal.StandardDeviation()}\n")
    #f.write(f"skewness: {mk_cal.skewness()}\n")
    #f.write(f"kurtosis: {mk_cal.kurtosis()}\n")
    #f.write("\n")


    #plt.plot(mk_cal_dic.keys(), mk_cal_dic.values(), 'o--', linewidth=1, label=f"subset {index}")
    #print("skewness")
    skewness_list.append(mk_cal_dic['skewness'])
    kurtosis_list.append(mk_cal_dic['kurtosis'])
    #print(f" skewness {mk_cal_dic['skewness']}")
    #print("kurtosis")
    #print(f" kurtosis {mk_cal_dic['kurtosis']}")

    index += 1

f.close()

print(skewness_list)
print(kurtosis_list)

skewness_list_cal = Cal_sample_statistic(skewness_list)
mu = skewness_list_cal.mean()
sigma = skewness_list_cal.StandardDeviation()
print(f"mu = {mu}, sigma = {sigma}")

kurtosis_list_cal = Cal_sample_statistic(kurtosis_list)
mu = kurtosis_list_cal.mean()
sigma = kurtosis_list_cal.StandardDeviation()
print(f"mu = {mu}, sigma = {sigma}")
# Out:
# [1.3603894543607413, 1.1453658145349797, 1.6742002079310436, 1.2711493942805294, 1.2335040158445711, 1.2010593388935613, 1.3610156175275385, 1.5658697600594647, 1.3498644743368338, 1.4449958076654776]
# [5.69797433439668, 4.809593758015298, 7.689490559018485, 5.036320380968432, 4.995749759633996, 5.0476291669554465, 5.70076039108694, 6.283655341592659, 5.802680935519187, 6.225988522370861]
# mu = 1.360741388543474, sigma = 0.1560937100024589
# mu = 5.728984314955797, sigma = 0.8205112635488622

# %%
"""
1. mean
2. Geometric mean (can you?!)
3. median
4. mode
5. variance
6. StandardDeviation
7. skewness
8. kurtosis
"""

numlist= range(10)
plt.figure()
plt.plot(0, mk4_cal_dic["kurtosis"], 'bo-', linewidth=1, label="Dataset4.txt")
index =1
for dataset in subset_list:
    mk_cal = Cal_sample_statistic(dataset)
    mean_val = mk_cal.kurtosis()
    plt.plot(index, mean_val, 'o--', linewidth=1, label=index)
    index += 1
plt.title(f"kurtosis plot of subsets of Dataset4.txt")
#plt.legend(loc='best')
plt.show()

# %%
D2 = handling_txts("Dataset2.txt")
D2_list = D2.rd_savetolist()
D2_cal = Cal_sample_statistic(D2_list)

n = 1000
result = [D2_list[i * n:(i + 1) * n] for i in range((len(D2_list) + n - 1) // n )] 

print(len(result[0]))
# Out:
# 1000

# %%
sub_mean_list = []
for subset in result:
    sub_cal = Cal_sample_statistic(subset)
    sub_mean = sub_cal.mean()
    sub_mean_list.append(sub_mean)

plt.figure(figsize=(30,10))
plt.plot(sub_mean_list, 'bo--', linewidth=1)
plt.legend(loc='upper left')
plt.title(f"Average plot of subsets of Dataset2.txt")
plt.show()

# newfile.py
f = open("hw1_proC.txt", 'w')

mk_cal = Cal_sample_statistic(sub_mean_list)

f.write(f"<calculate the following for subset Dataset2>\n")
f.write(f"mean: {mk_cal.mean()}\n")
f.write(f"geo_mean: {mk_cal.geo_mean()}\n")
f.write(f"median: {mk_cal.median()}\n")
f.write(f"mode: {mk_cal.mode()}\n")
f.write(f"variance: {mk_cal.variance()}\n")
f.write(f"StandardDeviation: {mk_cal.StandardDeviation()}\n")
f.write(f"skewness: {mk_cal.skewness()}\n")
f.write(f"kurtosis: {mk_cal.kurtosis()}\n")
f.write("\n")

f.close()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from math import pi

# sphere, cylinder, cone, cube

r = 1
h = 1

sphere_Surface_Area = 4*pi*r*r
cylinder_Surface_Area = 2*pi*r*h + 2*pi*r*r
cone_Surface_Area = pi*r*(r+h)
cube_Surface_Area = 6*r*r

sphere_volume = 4/3*pi*r*r*r
cylinder_volume = pi*r*r*h
cone_volume = 1/3*pi*r*r*h
cube_volume = r*r*r

#sphere_svr = sphere_Surface_Area/sphere_volume
#cylinder_svr = cylinder_Surface_Area/cylinder_volume
#cone_svr = cone_Surface_Area/cone_volume
#cube_svr = cube_Surface_Area/cube_volume

# %%
sphere_svr_list = []
cylinder_svr_list = []
cone_svr_list = []
cube_svr_list = []

for i in range(100):
    for j in range(100):
        r=i+1
        h=j+1
        sphere_svr = 3/r
        cylinder_svr = (2/r)+(2/h)
        cone_svr = (pi*r*r+pi*r*(r*r+h*h)*(1/2))/(1/3*pi*r*r*h)
        cube_svr = 6/r

        sphere_svr_list.append(sphere_svr)
        cylinder_svr_list.append(cylinder_svr)
        cone_svr_list.append(cone_svr)
        cube_svr_list.append(cube_svr)

plt.figure()
plt.plot(sphere_svr_list, 'r-', linewidth=0.5)
plt.plot(cube_svr_list, 'v-', linewidth=0.5)
plt.legend(loc='upper left')
plt.title(f"Surface-area-to-volume ratio of 3D objects sphere, cube ")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
